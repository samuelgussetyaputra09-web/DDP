# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelgussetyaputra09-web/DDP/blob/main/pratikum5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
namakendaraan = "beat"
jeniskendaraan = "motor"
cckendaraan = 200
warnakendaraan = "putih"
rodakendaraan = 2

data_kendaraan = [namakendaraan, jeniskendaraan, cckendaraan, warnakendaraan, rodakendaraan, ]
print(data_kendaraan)

hargakendaraan = 5000
tipekendaraan = "matic"

data_kendaraan.append(hargakendaraan)
data_kendaraan.append(tipekendaraan)
print(data_kendaraan)

merkkendaraan = "honda"
data_kendaraan.insert(2, merkkendaraan)
print(data_kendaraan)
# Out:
# ['beat', 'motor', 200, 'putih', 2]
# ['beat', 'motor', 200, 'putih', 2, 5000, 'matic']
# ['beat', 'motor', 'honda', 200, 'putih', 2, 5000, 'matic']

# %%
2
pilihan = input("""
silahkan pilih menu yang diinginkan
===================================
1. luas persegi
2. luas lingkaran
3. luas segitiga
===================================
kirimkan hanya angka saja
jawaban = """)

#luas persegi
match pilihan :
  case "1":
   sisi = int(input("sisi= "))
   luas = sisi * sisi
   print(f"luas persegi dengan sisi [sisi] adalah [luas]")

   # luas lingkaran
  case "2" :
   jarijari = int(input("jarijari= "))
   luas = 3.14 * jarijari**2
   print(f"luas lingkaran dengan jari jari [jarijari] adalah [luas]")

   #luas segitiga
  case "3" :
   tinggi = float(input("alas= "))
   luas = 0.5 * alas * tinggi
   print(f"luas segitiga adalah [luas]")

  case _:
    print("salah pilih!silahkan pilih 1, 2, atau 3 saja")
# Out:
# silahkan pilih menu yang diinginkan
# ...
# 1. luas persegi
# 2. luas lingkaran
# 3. luas segitiga
# ...
# kirimkan hanya angka saja
# jawaban = 2
# jarijari= 2
# luas lingkaran dengan jari jari [jarijari] adalah [luas]
